# %%
import pandas as pd

# %%
df0 = pd.read_csv('./result/repurpose_broad/CNN_CNN_BindingDB.txt', delimiter = '\t')
df0
# Out:
#       RANK                  Drug Name Target Name  Binding Score
# 0        1                 Tacrolimus        KRAS           0.59
# 1        2             Detrothyronine        KRAS           0.60
# 2        3               Liothyronine        KRAS           0.66
# 3        4                Zafirlukast        KRAS           0.91
# 4        5                Laropiprant        KRAS           0.99
# ...    ...                        ...         ...            ...
# 6106  6107                        UNK        KRAS     8141861.05
# 6107  6108                  DL-Xylose        KRAS     8480980.30
# 6108  6109    S-Isopropyl-isothiourea        KRAS     8525125.46
# 6109  6110               D(+)-Glucose        KRAS     8623100.78
# 6110  6111  Pyrimidine-4-carbonitrile        KRAS     9134665.40
#
# [6111 rows x 4 columns]

# %%
df1 = pd.read_csv('./result/repurpose_broad/CNN_CNN_BindingDB_IC50.txt', delimiter = '\t')
df1
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                         Aclidinium        KRAS
# 1        2  N-Hydroxy-1-(2-methoxyethyl)-4-[4-[4-(trifluor...        KRAS
# 2        3  N-Methyl-N-[2-[[[2-[(2-oxo-1,3-dihydroindol-5-...        KRAS
# 3        4                              PF-00562271 free base        KRAS
# 4        5                                       Tazemetostat        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                        Pinocembrin        KRAS
# 6107  6108                     (5-Fluoropyridin-3-yl)methanol        KRAS
# 6108  6109                            5-Fluoropyrimidin-2-one        KRAS
# 6109  6110             2'-Deoxy-2'-fluoro-2'-C-methylcytidine        KRAS
# 6110  6111                                           Amrinone        KRAS
#
#       Binding Score
# 0             19.91
# 1             53.30
# ...

# %%
df2 = pd.read_csv('./result/repurpose_broad/CNN_CNN_DAVIS.txt', delimiter = '\t')
df2
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                          Motolimod        KRAS
# 1        2                                          Adarotene        KRAS
# 2        3  1-Butyl-3-(3-hydroxypropyl)-8-(3-tricyclo[3.3....        KRAS
# 3        4                                         Xanomeline        KRAS
# 4        5  6-[3-(1-Adamantyl)-4-hydroxyphenyl]-2-naphthal...        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                        Cobimetinib        KRAS
# 6107  6108                                        Remoxipride        KRAS
# 6108  6109  (2S)-2-Amino-N-[(2R)-1-(4-butanoyl-4-phenylpip...        KRAS
# 6109  6110  (R)-2-(3-Chloro-6-fluorobenzo[b]thiophene-2-ca...        KRAS
# 6110  6111                                       Zaurategrast        KRAS
#
#       Binding Score
# 0           1516.17
# 1           1776.17
# ...

# %%
df3 = pd.read_csv('./result/repurpose_broad/Daylight_AAC_BindingDB.txt', delimiter = '\t')
df3
# Out:
#       RANK                              Drug Name Target Name  Binding Score
# 0        1              Dorzolamide, (+/-)-(cis)-        KRAS           0.42
# 1        2  Ascomycin, Streptomyces hygroscopicus        KRAS           0.51
# 2        3                             Tacrolimus        KRAS           0.64
# 3        4                           Liothyronine        KRAS           0.64
# 4        5                         Detrothyronine        KRAS           0.64
# ...    ...                                    ...         ...            ...
# 6106  6107                            DL-Tyrosine        KRAS      891750.24
# 6107  6108                              Isoniazid        KRAS     1008725.99
# 6108  6109                          Amitriptyline        KRAS     1015841.99
# 6109  6110                              Foscarnet        KRAS     1349171.35
# 6110  6111                      2-Methylimidazole        KRAS     1949538.31
#
# [6111 rows x 4 columns]

# %%
df4 = pd.read_csv('./result/repurpose_broad/Daylight_AAC_BindingDB_IC50.txt', delimiter = '\t')
df4
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                         Batimastat        KRAS
# 1        2                                       Mifepristone        KRAS
# 2        3                                          Ilomastat        KRAS
# 3        4                                      Brexpiprazole        KRAS
# 4        5                                     Trichostatin A        KRAS
# ...    ...                                                ...         ...
# 6106  6107  (2R,3R,4S,5S,6S)-2-[[(2R,3S,4R,4Ar,6R,7R,8aS)-...        KRAS
# 6107  6108                                         Xylostasin        KRAS
# 6108  6109  (2R,3S,4R,5R,6R)-5-Amino-2-(aminomethyl)-6-[(1...        KRAS
# 6109  6110                                        Theobromine        KRAS
# 6110  6111  (2S)-4-Amino-N-[(1R,2S,3S,4R,5S)-5-amino-2-[(3...        KRAS
#
#       Binding Score
# 0             34.79
# 1             42.07
# ...

# %%
df5 = pd.read_csv('./result/repurpose_broad/Daylight_AAC_DAVIS.txt', delimiter = '\t')
df5
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                    Arcyriaflavin a        KRAS
# 1        2                                       CID 72547474        KRAS
# 2        3                                          Tamatinib        KRAS
# 3        4  N-[3-[[2-[4-[[1-(2-Fluoroethyl)azetidin-3-yl]a...        KRAS
# 4        5  9-Hydroxy-4-phenyl-6H-pyrrolo[3,4-C]carbazole-...        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                          Vatalanib        KRAS
# 6107  6108                               BMS-345541 free base        KRAS
# 6108  6109                                          Pelitinib        KRAS
# 6109  6110  (E)-N-[4-[3-Chloro-4-[(3-fluorophenyl)methoxy]...        KRAS
# 6110  6111                                          Neratinib        KRAS
#
#       Binding Score
# 0            162.35
# 1            162.46
# ...

# %%
df6 = pd.read_csv('./result/repurpose_broad/Daylight_AAC_KIBA.txt', delimiter = '\t')
df6
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                        Famciclovir        KRAS
# 1        2                                        Telenzepine        KRAS
# 2        3                                      Ciprofloxacin        KRAS
# 3        4                                           Physcion        KRAS
# 4        5                                   Ingenol mebutate        KRAS
# ...    ...                                                ...         ...
# 6106  6107                               Triethylenetetramine        KRAS
# 6107  6108                                           Urethane        KRAS
# 6108  6109  3-((5-(2,3-Dichlorophenyl)-1H-tetrazol-1-yl)me...        KRAS
# 6109  6110                                             Harman        KRAS
# 6110  6111                                         Olomoucine        KRAS
#
#       Binding Score
# 0              0.00
# 1              0.00
# ...

# %%
df7 = pd.read_csv('./result/repurpose_broad/Morgan_AAC_BindingDB.txt', delimiter = '\t')
df7
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  4-{2-[(7-Amino-2-Furan-2-Yl[1,2,4]triazolo[1,5...        KRAS
# 1        2  2-(Furan-2-yl)-7-phenethyl-7H-pyrazolo[4,3-e][...        KRAS
# 2        3                          Dorzolamide, (+/-)-(cis)-        KRAS
# 3        4  2-[(3R,5R,6S)-5-(3-Chlorophenyl)-6-(4-chloroph...        KRAS
# 4        5                                       Zolmitriptan        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                      Robison ester        KRAS
# 6107  6108  N-[(2S,4S,5S)-2,4,5-Trihydroxy-6-(hydroxymethy...        KRAS
# 6108  6109                                          Nicoxamat        KRAS
# 6109  6110                                    alpha-D-Glucose        KRAS
# 6110  6111  (2E)-2-[[4-(3,4-Dichlorophenyl)-1,3-thiazol-2-...        KRAS
#
#       Binding Score
# 0              2.84
# 1              3.12
# ...

# %%
df8 = pd.read_csv('./result/repurpose_broad/Morgan_AAC_BindingDB_IC50.txt', delimiter = '\t')
df8
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  Methyl N-[1-[[4-[3-[5-chloro-2-fluoro-3-(metha...        KRAS
# 1        2  Urea, N-(2-((3-(2-cyanophenoxy)-2-hydroxypropy...        KRAS
# 2        3                                          Dovitinib        KRAS
# 3        4  2-(2',3-Dimethyl-[2,4'-bipyridin]-5-yl)-N-(5-(...        KRAS
# 4        5                                        Indatraline        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                         Cephradine        KRAS
# 6107  6108  (7R)-7-[[(2R)-2-Amino-2-cyclohexa-1,4-dien-1-y...        KRAS
# 6108  6109                        7-Aminocephalosporanic acid        KRAS
# 6109  6110                                      Valproic acid        KRAS
# 6110  6111                                       Arundic acid        KRAS
#
#       Binding Score
# 0             23.07
# 1             30.21
# ...

# %%
df9 = pd.read_csv('./result/repurpose_broad/Morgan_AAC_DAVIS.txt', delimiter = '\t')
df9
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  (15S,16S)-16-Hydroxy-16-(hydroxymethyl)-15-met...        KRAS
# 1        2  (2S,3R,4R,6R,18S)-18-Hydroxy-3-methoxy-2-methy...        KRAS
# 2        3                                          Sunitinib        KRAS
# 3        4  28-Oxa-4,14,19-triazaoctacyclo[12.11.2.115,18....        KRAS
# 4        5                                          Toceranib        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                         Tandutinib        KRAS
# 6107  6108                                           Afatinib        KRAS
# 6108  6109                                         Crizotinib        KRAS
# 6109  6110                                     (S)-Crizotinib        KRAS
# 6110  6111                                          Dasatinib        KRAS
#
#       Binding Score
# 0            123.89
# 1            282.29
# ...

# %%
df10 = pd.read_csv('./result/repurpose_broad/Morgan_AAC_KIBA.txt', delimiter = '\t')
df10
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  4-{2-[(7-Amino-2-Furan-2-Yl[1,2,4]triazolo[1,5...        KRAS
# 1        2  2-(Furan-2-yl)-7-phenethyl-7H-pyrazolo[4,3-e][...        KRAS
# 2        3                          Dorzolamide, (+/-)-(cis)-        KRAS
# 3        4  2-[(3R,5R,6S)-5-(3-Chlorophenyl)-6-(4-chloroph...        KRAS
# 4        5                                       Zolmitriptan        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                      Robison ester        KRAS
# 6107  6108  N-[(2S,4S,5S)-2,4,5-Trihydroxy-6-(hydroxymethy...        KRAS
# 6108  6109                                          Nicoxamat        KRAS
# 6109  6110                                    alpha-D-Glucose        KRAS
# 6110  6111  (2E)-2-[[4-(3,4-Dichlorophenyl)-1,3-thiazol-2-...        KRAS
#
#       Binding Score
# 0              2.84
# 1              3.12
# ...

# %%
df11 = pd.read_csv('./result/repurpose_broad/Morgan_CNN_BindingDB.txt', delimiter = '\t')
df11
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                        Laropiprant        KRAS
# 1        2                                 Mometasone furoate        KRAS
# 2        3  4-{2-[(7-Amino-2-Furan-2-Yl[1,2,4]triazolo[1,5...        KRAS
# 3        4                                     Pirinixic acid        KRAS
# 4        5                                         Olcegepant        KRAS
# ...    ...                                                ...         ...
# 6106  6107  3-(4-((3-Phenoxybenzyl)amino)phenyl)propanoic ...        KRAS
# 6107  6108                                           Thiamine        KRAS
# 6108  6109  (2E)-2-[[4-(3,4-Dichlorophenyl)-1,3-thiazol-2-...        KRAS
# 6109  6110                                    alpha-D-Glucose        KRAS
# 6110  6111                                       CID 16198383        KRAS
#
#       Binding Score
# 0              0.38
# 1              0.62
# ...

# %%
df12 = pd.read_csv('./result/repurpose_broad/Morgan_CNN_BindingDB_IC50.txt', delimiter = '\t')
df12
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                                UNK        KRAS
# 1        2  N4-(3-Bromophenyl)-N6-methylpyrido[3,4-d]pyrim...        KRAS
# 2        3  4-Methyl-N-[4-[(4-methylpiperazin-1-yl)methyl]...        KRAS
# 3        4                                         Aclidinium        KRAS
# 4        5                                          Ponatinib        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                   Lactobionic acid        KRAS
# 6107  6108  (2S,4E)-2-Hydroxy-4-[[(3S)-3-hydroxy-5-[(E)-3-...        KRAS
# 6108  6109                                           Cytidine        KRAS
# 6109  6110  N-[[1-[[4-(Hydroxyiminomethyl)pyridin-1-ium-1-...        KRAS
# 6110  6111                                    Aurothioglucose        KRAS
#
#       Binding Score
# 0              0.35
# 1              0.49
# ...

# %%
df13 = pd.read_csv('./result/repurpose_broad/Morgan_CNN_DAVIS.txt', delimiter = '\t')
df13
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  (2S,3R,4R,6R,18S)-18-Hydroxy-3-methoxy-2-methy...        KRAS
# 1        2  (15S,16S)-16-Hydroxy-16-(hydroxymethyl)-15-met...        KRAS
# 2        3  28-Oxa-4,14,19-triazaoctacyclo[12.11.2.115,18....        KRAS
# 3        4                                        Nvp-tae 684        KRAS
# 4        5                                           Asp-3026        KRAS
# ...    ...                                                ...         ...
# 6106  6107  6-(2,6-Dichlorophenyl)-2-[4-[2-(diethylamino)e...        KRAS
# 6107  6108                                       CID 56649281        KRAS
# 6108  6109  6-(2,4-Dichlorophenyl)-8-ethyl-2-(3-fluoro-4-p...        KRAS
# 6109  6110                                          Dasatinib        KRAS
# 6110  6111                                          Bosutinib        KRAS
#
#       Binding Score
# 0             25.17
# 1             42.82
# ...

# %%
df14 = pd.read_csv('./result/repurpose_broad/MPNN_CNN_BindingDB.txt', delimiter = '\t')
df14
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                        Levobunolol        KRAS
# 1        2           1,6-Bis(cyclohexyloximinocarbonyl)hexane        KRAS
# 2        3  (R)-6-(7-Hydroxy-6,7-dihydro-5H-pyrrolo[1,2-c]...        KRAS
# 3        4  5-Methyl-3-[3-[4-[2-(2,2,2-trifluoroethoxy)phe...        KRAS
# 4        5                                        Glutathione        KRAS
# ...    ...                                                ...         ...
# 6106  6107    2-Morpholino-6-(thianthren-1-yl)-4H-pyran-4-one        KRAS
# 6107  6108                                         Pregabalin        KRAS
# 6108  6109  (1S,2R,9R,17S)-13-Oxido-7-aza-13-azoniatetracy...        KRAS
# 6109  6110                                       Pyruvic acid        KRAS
# 6110  6111                                           Nylidrin        KRAS
#
#       Binding Score
# 0      0.000000e+00
# 1      0.000000e+00
# ...

# %%
df15 = pd.read_csv('./result/repurpose_broad/MPNN_CNN_BindingDB_IC50.txt', delimiter = '\t')
df15
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                        Levobunolol        KRAS
# 1        2  1-(2-Chloro-4-hydroxyphenyl)-tert-butylaminoet...        KRAS
# 2        3                                 Aminohippuric acid        KRAS
# 3        4  [2-[(10R,11S,13S,17R)-11,17-Dihydroxy-10,13-di...        KRAS
# 4        5                                         Tacrolimus        KRAS
# ...    ...                                                ...         ...
# 6106  6107  9H-Purine-2,6-diamine, N2-(2-aminocyclohexyl)-...        KRAS
# 6107  6108                                         Sinomenine        KRAS
# 6108  6109                                         Valpromide        KRAS
# 6109  6110                                     Benzyl alcohol        KRAS
# 6110  6111                                       Cinoctramide        KRAS
#
#       Binding Score
# 0      0.000000e+00
# 1      0.000000e+00
# ...

# %%
df16 = pd.read_csv('./result/repurpose_broad/MPNN_CNN_DAVIS.txt', delimiter = '\t')
df16
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1           1,6-Bis(cyclohexyloximinocarbonyl)hexane        KRAS
# 1        2                                          Pelitinib        KRAS
# 2        3  4-(4-Fluoronaphthalen-1-yl)-6-isopropylpyrimid...        KRAS
# 3        4                                           Isoxepac        KRAS
# 4        5  (6S,9R,11S,13S,17R)-17-Acetyl-9-fluoro-11,17-d...        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                          Iodixanol        KRAS
# 6107  6108                                        Dipyrocetyl        KRAS
# 6108  6109  2-Cyclohexyl-6-methoxy-N-methyl-N-(1-propan-2-...        KRAS
# 6109  6110                                        Decoquinate        KRAS
# 6110  6111                                   N-Oleoyldopamine        KRAS
#
#       Binding Score
# 0      0.000000e+00
# 1      0.000000e+00
# ...

# %%
df17 = pd.read_csv('./result/repurpose_broad/MPNN_CNN_KIBA.txt', delimiter = '\t')
df17
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1                                      Emtricitabine        KRAS
# 1        2                                       Oxyclozanide        KRAS
# 2        3                                        Bekanamycin        KRAS
# 3        4                                       CID 16198383        KRAS
# 4        5                                            Precose        KRAS
# ...    ...                                                ...         ...
# 6106  6107  [(9E,19E,21Z)-2,15,17,27,29-Pentahydroxy-11-me...        KRAS
# 6107  6108                                       Ethylparaben        KRAS
# 6108  6109  (6-Iodo-2-methyl-1-(2-morpholinoethyl)-1H-indo...        KRAS
# 6109  6110  7-[[(2R)-2-Amino-2-phenylacetyl]amino]-3-chlor...        KRAS
# 6110  6111  N-(2-(4'-Cyano-[1,1'-biphenyl]-4-yl)propyl)pro...        KRAS
#
#       Binding Score
# 0              0.00
# 1              0.00
# ...

# %%
df18 = pd.read_csv('./result/repurpose_broad/Transformer_CNN_BindingDB.txt', delimiter = '\t')
df18
# Out:
#       RANK                                          Drug Name Target Name  \
# 0        1  2-[(3R,5R,6S)-5-(3-Chlorophenyl)-6-(4-chloroph...        KRAS
# 1        2                                         Tacrolimus        KRAS
# 2        3                                         Mometasone        KRAS
# 3        4  [(1S,3S,5Z,7R,8Z,11S,12S,13E,15S,17R,21R,23S,2...        KRAS
# 4        5                                       Liothyronine        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                    Cetylpyridinium        KRAS
# 6107  6108                                          Triclosan        KRAS
# 6108  6109                                         Dobutamine        KRAS
# 6109  6110                                              Didox        KRAS
# 6110  6111  N-(2-(3,4-Dichlorophenyl)ethyl)-N-methyl-2-(di...        KRAS
#
#       Binding Score
# 0              0.46
# 1              0.55
# ...

# %%
# 6개의 pretrained 모델 합침
df19 = pd.read_csv('./result/kras_repurposing.txt', delimiter = '\t')
df19
# Out:
#       RANK              Drug Name Target Name  Binding Score
# 0        1                 GW0742        KRAS           4.91
# 1        2            Fulvestrant        KRAS          14.25
# 2        3              Meropenem        KRAS          16.14
# 3        4          Dexamethasone        KRAS          19.37
# 4        5          Norethindrone        KRAS          19.76
# ...    ...                    ...         ...            ...
# 6106  6107          Octanoic acid        KRAS     1766003.22
# 6107  6108              Erteberel        KRAS     1800665.88
# 6108  6109  3-Hydroxybutyric acid        KRAS     1928627.70
# 6109  6110             Isoflurane        KRAS     1960784.37
# 6110  6111          Robison ester        KRAS     2174754.46
#
# [6111 rows x 4 columns]

# %% [markdown]
# KIBA 데이터셋로 훈련된 모델 Binding Score 상위 50개 추출

# %%
kiba1 = df6.tail(50)
kiba2 = df10.tail(50)
kiba3 = df17.tail(50)
kiba = pd.concat([kiba1, kiba2, kiba3])
kiba
# Out:
#       RANK                                          Drug Name Target Name  \
# 6061  6062                               Allyl isothiocyanate        KRAS
# 6062  6063                           Methanesulfonyl fluoride        KRAS
# 6063  6064  6-Methoxy-1-naphthalen-1-yl-9H-pyrido[3,4-b]in...        KRAS
# 6064  6065                                          Sarcosine        KRAS
# 6065  6066                           Dioxosilane;oxomagnesium        KRAS
# ...    ...                                                ...         ...
# 6106  6107  [(9E,19E,21Z)-2,15,17,27,29-Pentahydroxy-11-me...        KRAS
# 6107  6108                                       Ethylparaben        KRAS
# 6108  6109  (6-Iodo-2-methyl-1-(2-morpholinoethyl)-1H-indo...        KRAS
# 6109  6110  7-[[(2R)-2-Amino-2-phenylacetyl]amino]-3-chlor...        KRAS
# 6110  6111  N-(2-(4'-Cyano-[1,1'-biphenyl]-4-yl)propyl)pro...        KRAS
#
#       Binding Score
# 6061           0.07
# 6062           0.07
# ...

# %%
kiba['Drug Name'].value_counts()
# Out:
# UNK                                                                                                  3
# (R)-Amygdalin                                                                                        2
# Phenol                                                                                               2
# Dioxosilane;oxomagnesium                                                                             2
# (2E)-2-[[4-(3,4-Dichlorophenyl)-1,3-thiazol-2-yl]hydrazinylidene]-3-(2-nitrophenyl)propanoic acid    2
#                                                                                                     ..
# Nastorazepide                                                                                        1
# Sulfapyridine                                                                                        1
# 3-((5-(2,3-Dichlorophenyl)-1H-tetrazol-1-yl)methyl)pyridine                                          1
# ...

# %% [markdown]
# Davis 데이터로 훈련된 모델 Binding Score 상위 50개 추출

# %%
davis1 = df2.tail(50)
davis2 = df5.tail(50)
davis3 = df9.tail(50)
davis4 = df13.tail(50)
davis5 = df16.tail(50)
davis = pd.concat([davis1, davis2, davis3, davis4, davis5])
davis
# Out:
#       RANK                                          Drug Name Target Name  \
# 6061  6062                                        Deferiprone        KRAS
# 6062  6063                                        Carfilzomib        KRAS
# 6063  6064  (1R,3R,6R,7S,8S,10R,13S,16S,17R)-8-Tert-butyl-...        KRAS
# 6064  6065                                    Cot inhibitor-1        KRAS
# 6065  6066  [(2S,3S,5S,8R,9S,10S,13S,14S,16S)-17-Acetyloxy...        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                          Iodixanol        KRAS
# 6107  6108                                        Dipyrocetyl        KRAS
# 6108  6109  2-Cyclohexyl-6-methoxy-N-methyl-N-(1-propan-2-...        KRAS
# 6109  6110                                        Decoquinate        KRAS
# 6110  6111                                   N-Oleoyldopamine        KRAS
#
#       Binding Score
# 6061   1.310917e+04
# 6062   1.312673e+04
# ...

# %%
davis['Drug Name'].value_counts()
# Out:
# UNK                                                                                        3
# Lapatinib                                                                                  2
# Brivanib                                                                                   2
# N-(4-(3-Chloro-4-(3-fluorobenzyloxy)phenylamino)quinazolin-6-yl)acrylamide                 2
# Tandutinib                                                                                 2
#                                                                                           ..
# 4'-((1R,2S)-2-Aminocyclopropyl)-[1,1'-biphenyl]-3-ol                                       1
# N-Oleoyldopamine                                                                           1
# Sipatrigine                                                                                1
# Deferiprone                                                                                1
# ...

# %% [markdown]
# BindingDB으로 훈련된 모델 Binding Score 상위50개 추출

# %%
bind1 = df0.tail(50)
bind2 = df1.tail(50)
bind3 = df3.tail(50)
bind4 = df4.tail(50)
bind5 = df7.tail(50)
bind6 = df8.tail(50)
bind7 = df11.tail(50)
bind8 = df12.tail(50)
bind9 = df14.tail(50)
bind10 = df15.tail(50)
bind11 = df18.tail(50)
bind = pd.concat([bind1, bind2, bind3, bind4, bind5, bind6, bind7, bind8, bind9, bind10, bind11])
bind
# Out:
#       RANK                                          Drug Name Target Name  \
# 6061  6062                                     Carglumic acid        KRAS
# 6062  6063                                       Pyrazinamide        KRAS
# 6063  6064                                         Chromocarb        KRAS
# 6064  6065                                     4-Chlorophenol        KRAS
# 6065  6066  Ethanaminium, N-(fluoromethyl)-2-hydroxy-N,N-d...        KRAS
# ...    ...                                                ...         ...
# 6106  6107                                    Cetylpyridinium        KRAS
# 6107  6108                                          Triclosan        KRAS
# 6108  6109                                         Dobutamine        KRAS
# 6109  6110                                              Didox        KRAS
# 6110  6111  N-(2-(3,4-Dichlorophenyl)ethyl)-N-methyl-2-(di...        KRAS
#
#       Binding Score
# 6061     3088816.50
# 6062     3121396.96
# ...

# %%
bind['Drug Name'].value_counts()
# Out:
# UNK                                                                    10
# Undecylenic acid                                                        4
# N-[(2S,4S,5S)-2,4,5-Trihydroxy-6-(hydroxymethyl)oxan-3-yl]acetamide     4
# Amitriptyline                                                           4
# L-Proline                                                               4
#                                                                        ..
# Enilconazole                                                            1
# Bempedoic acid                                                          1
# 2-Ethyl-3-hydroxy-6-methylpyridine                                      1
# 2,2-Dimethylbutyric acid                                                1
# Cloxacillin                                                             1
# Name: Drug Name, Length: 446, dtype: int64

# %% [markdown]
# Pretrained 모델 전체의 Binding Score 상위 50개 추출 후 중복된 값 확인 + 파일로 저장

# %%
all_pre = pd.concat([df0.tail(30), df1.tail(30), df2.tail(30), df3.tail(30), df4.tail(30), df5.tail(30), df6.tail(30), df7.tail(30), df8.tail(30), df9.tail(30), df10.tail(30), df11.tail(30), df12.tail(30), df13.tail(30), df14.tail(30), df15.tail(30), df16.tail(30), df17.tail(30), df18.tail(30)])
all_pre['Drug Name'].value_counts()
# Out:
# UNK                                                                                                                            12
# Amitriptyline                                                                                                                   5
# alpha-D-Glucose                                                                                                                 5
# Streptozocin                                                                                                                    4
# [(2R,3S,4R)-5-(6-Aminopurin-9-yl)-3,4-dihydroxy-2-oxolanyl]methyl dihydrogen phosphate                                          4
#                                                                                                                                ..
# (16E)-14-Methyl-20-oxa-5,7,14,27-tetrazatetracyclo[19.3.1.12,6.18,12]heptacosa-1(25),2(27),3,5,8,10,12(26),16,21,23-decaene     1
# ...

# %%
test = all_pre['Drug Name'].value_counts()

# %%
test = pd.DataFrame(test)
test
# Out:
#                                                     Drug Name
# UNK                                                        12
# Amitriptyline                                               5
# alpha-D-Glucose                                             5
# Streptozocin                                                4
# [(2R,3S,4R)-5-(6-Aminopurin-9-yl)-3,4-dihydroxy...          4
# ...                                                       ...
# (16E)-14-Methyl-20-oxa-5,7,14,27-tetrazatetracy...          1
# Paraxanthine                                                1
# (R)-Oxiracetam                                              1
# 3-(2,4-Dichlorophenyl)-4-(1-methyl-1H-indol-3-y...          1
# Fluorescein                                                 1
#
# [464 rows x 1 columns]

# %% [markdown]
# 앙상블된 pretrained 모델의 Binding Score 상위 50개 drug 목록 확인

# %%
df19['Drug Name'].tail(50)
# Out:
# 6061    4-Bromo-N-(6-methoxy-1,3-dimethyl-2-oxobenzimi...
# 6062    (6R,7R)-3-[(4-Carbamoylpyridin-1-ium-1-yl)meth...
# 6063                                            Naloxegol
# 6064                                              Ipodate
# 6065                                          Sulconazole
# 6066                                           Gsk-461364
# 6067                                           Pipobroman
# 6068                                           Tolazamide
# 6069                                             Imipenem
# 6070                                           Delanzomib
# 6071                                         Pimonidazole
# 6072                                         Valacyclovir
# 6073                                       Norepinephrine
# 6074                                           C9H16N2O4S
# 6075                                            Ceftiofur
# 6076                             6-Thiazolylquinazoline 6
# ...

# %% [markdown]
# 모든 모델 추론 결과의 binding score 상위 30개 저장

# %%
f0 = df0.tail(30)
f0.to_csv('./result/tail30/CNN_CNN_BindingDB.txt', sep = '\t', index = False)
f1 = df1.tail(30)
f1.to_csv('./result/tail30/CNN_CNN_BindingDB_IC50.txt', sep = '\t', index = False)
f2 = df2.tail(30)
f2.to_csv('./result/tail30/CNN_CNN_DAVIS.txt', sep = '\t', index = False)
f3 = df3.tail(30)
f3.to_csv('./result/tail30/Daylight_AAC_BindingDB.txt', sep = '\t', index = False)
f4 = df4.tail(30)
f4.to_csv('./result/tail30/Daylight_AAC_BindingDB_IC50.txt', sep = '\t', index = False)
f5 = df5.tail(30)
f5.to_csv('./result/tail30/Daylight_AAC_DAVIS.txt', sep = '\t', index = False)
f6 = df6.tail(30)
f6.to_csv('./result/tail30/Daylight_AAC_KIBA.txt', sep = '\t', index = False)
f7 = df7.tail(30)
f7.to_csv('./result/tail30/Morgan_AAC_BindingDB.txt', sep = '\t', index = False)
f8 = df8.tail(30)
f8.to_csv('./result/tail30/Morgan_AAC_BindingDB_IC50.txt', sep = '\t', index = False)
f9 = df9.tail(30)
f9.to_csv('./result/tail30/Morgan_AAC_DAVIS.txt', sep = '\t', index = False)
f10 = df10.tail(30)
f10.to_csv('./result/tail30/Morgan_AAC_KIBA.txt', sep = '\t', index = False)
f11 = df11.tail(30)
f11.to_csv('./result/tail30/Morgan_CNN_BindingDB.txt', sep = '\t', index = False)
f12 = df12.tail(30)
f12.to_csv('./result/tail30/Morgan_CNN_BindingDB_IC50.txt', sep = '\t', index = False)
f13 = df13.tail(30)
f13.to_csv('./result/tail30/Morgan_CNN_DAVIS.txt', sep = '\t', index = False)
f14 = df14.tail(30)
f14.to_csv('./result/tail30/MPNN_CNN_BindingDB.txt', sep = '\t', index = False)
f15 = df15.tail(30)
f15.to_csv('./result/tail30/MPNN_CNN_BindingDB_IC50.txt', sep = '\t', index = False)
f16 = df16.tail(30)
f16.to_csv('./result/tail30/MPNN_CNN_DAVIS.txt', sep = '\t', index = False)
f17 = df17.tail(30)
f17.to_csv('./result/tail30/MPNN_CNN_KIBA.txt', sep = '\t', index = False)
f18 = df18.tail(30)
f18.to_csv('./result/tail30/Transformer_CNN_BindingDB.txt', sep = '\t', index = False)
f19 = df19.tail(30)
f19.to_csv('./result/tail30/ensemble_pretrained.txt', sep = '\t', index = False)

# %%
test.to_csv("cound_drug_name.txt", sep = '\t', index = True)
