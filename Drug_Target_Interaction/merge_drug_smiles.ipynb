# %%
import pandas as pd
import numpy as np

# %%
drug = pd.read_csv('repurposing_drugs_20200324.csv')
drug
# Out:
#                         pert_iname clinical_phase  \
# 0              (R)-(-)-apomorphine       Launched
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6793                      8-M-PDOT    Preclinical
# 6794                    80841-78-7    Preclinical
# 6795               9-aminoacridine    Preclinical
# 6796           9-aminocamptothecin        Phase 2
# 6797   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa  \
# 0           dopamine receptor agonist
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6793       melatonin receptor agonist
# 6794                              NaN
# ...

# %%
info = pd.read_csv('repurposing_samples_20200324.csv')
info
# Out:
#                      broad_id           pert_iname  qc_incompatible  purity  \
# 0      BRD-K76022557-003-28-9  (R)-(-)-apomorphine                0   98.90
# 1      BRD-K76022557-003-02-7  (R)-(-)-apomorphine                0   97.34
# 2      BRD-K76022557-003-29-9  (R)-(-)-apomorphine                0   97.36
# 3      BRD-K76022557-001-03-9  (R)-(-)-apomorphine                0   95.80
# 4      BRD-K75516118-001-04-1     (R)-(-)-rolipram                0   93.92
# ...                       ...                  ...              ...     ...
# 13548  BRD-K63068307-001-10-9             ZSTK-474                0   96.15
# 13549  BRD-K63068307-001-08-9             ZSTK-474                0   98.66
# 13550  BRD-K28761384-001-10-9       zuclopenthixol                0   94.95
# 13551  BRD-K28761384-300-01-0       zuclopenthixol                0   97.19
# 13552  BRD-K00003448-001-01-9           zuranolone                0   92.59
#
# ...

# %%
info['pert_iname'].drop_duplicates()
# Out:
# 0                 (R)-(-)-apomorphine
# 4                    (R)-(-)-rolipram
# 7                        (R)-baclofen
# 9                    (S)-(+)-rolipram
# 12       [sar9,met(o2)11]-substance-p
#                      ...
# 13544                    zoxazolamine
# 13547                        ZSET1446
# 13548                        ZSTK-474
# 13550                  zuclopenthixol
# 13552                      zuranolone
# Name: pert_iname, Length: 6798, dtype: object

# %%
smiles = info[['pert_iname', 'smiles']]
smiles
# Out:
#                 pert_iname                                             smiles
# 0      (R)-(-)-apomorphine             CN1CCc2cccc-3c2[C@H]1Cc1ccc(O)c(O)c-31
# 1      (R)-(-)-apomorphine             CN1CCc2cccc-3c2[C@H]1Cc1ccc(O)c(O)c-31
# 2      (R)-(-)-apomorphine             CN1CCc2cccc-3c2[C@H]1Cc1ccc(O)c(O)c-31
# 3      (R)-(-)-apomorphine             CN1CCc2cccc-3c2[C@H]1Cc1ccc(O)c(O)c-31
# 4         (R)-(-)-rolipram               COc1ccc(cc1OC1CCCC1)[C@@H]1CNC(=O)C1
# ...                    ...                                                ...
# 13548             ZSTK-474    FC(F)c1nc2ccccc2n1-c1nc(nc(n1)N1CCOCC1)N1CCOCC1
# 13549             ZSTK-474    FC(F)c1nc2ccccc2n1-c1nc(nc(n1)N1CCOCC1)N1CCOCC1
# 13550       zuclopenthixol        OCCN1CCN(CC\C=C2\c3ccccc3Sc3ccc(Cl)cc23)CC1
# 13551       zuclopenthixol        OCCN1CCN(CC\C=C2\c3ccccc3Sc3ccc(Cl)cc23)CC1
# 13552           zuranolone  [H][C@@]12CC[C@H](C(=O)Cn3cc(cn3)C#N)[C@@]1(C)...
#
# [13553 rows x 2 columns]

# %%
smiles = smiles.drop_duplicates()
smiles
# Out:
#                          pert_iname  \
# 0               (R)-(-)-apomorphine
# 4                  (R)-(-)-rolipram
# 7                      (R)-baclofen
# 9                  (S)-(+)-rolipram
# 12     [sar9,met(o2)11]-substance-p
# ...                             ...
# 13544                  zoxazolamine
# 13547                      ZSET1446
# 13548                      ZSTK-474
# 13550                zuclopenthixol
# 13552                    zuranolone
#
#                                                   smiles
# 0                 CN1CCc2cccc-3c2[C@H]1Cc1ccc(O)c(O)c-31
# 4                   COc1ccc(cc1OC1CCCC1)[C@@H]1CNC(=O)C1
# 7                           NC[C@H](CC(O)=O)c1ccc(Cl)cc1
# 9                    COc1ccc(cc1OC1CCCC1)[C@H]1CNC(=O)C1
# 12     CC(C)C[C@H](NC(=O)CN(C)C(=O)[C@H](Cc1ccccc1)NC...
# ...                                                  ...
# 13544                                 Nc1nc2cc(Cl)ccc2o1
# 13547         O=C1N=C2C=CC=CN2C11Cc2ccccc2C1 |c:4,6,t:2|
# ...

# %%
drug_smiles = pd.merge(drug, smiles, on = 'pert_iname', how = 'left')
drug_smiles
# Out:
#                         pert_iname clinical_phase  \
# 0              (R)-(-)-apomorphine       Launched
# 1                 (R)-(-)-rolipram        Phase 1
# 2                     (R)-baclofen        Phase 3
# 3                 (S)-(+)-rolipram        Phase 1
# 4     [sar9,met(o2)11]-substance-p    Preclinical
# ...                            ...            ...
# 6803                      8-M-PDOT    Preclinical
# 6804                    80841-78-7    Preclinical
# 6805               9-aminoacridine    Preclinical
# 6806           9-aminocamptothecin        Phase 2
# 6807   9-anthracenecarboxylic-acid    Preclinical
#
#                                   moa  \
# 0           dopamine receptor agonist
# 1         phosphodiesterase inhibitor
# 2     benzodiazepine receptor agonist
# 3         phosphodiesterase inhibitor
# 4               tachykinin antagonist
# ...                               ...
# 6803       melatonin receptor agonist
# 6804                              NaN
# ...

# %%
drug_smiles.to_csv('clue_drug_smiles.txt', sep = '\t', index = False)
