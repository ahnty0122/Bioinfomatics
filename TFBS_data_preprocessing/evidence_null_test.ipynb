# %%
import pandas as pd

# %%
f = pd.read_csv("21_result.txt", delimiter = '\t')
# Out:
# C:\Users\Curigin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
f
# Out:
#            1  2                3         4         5          6  7  8  \
# 0         21  .  TF_binding_site   5011006   5011020   3.637832  -  .
# 1         21  .  TF_binding_site   5011006   5011020   3.637832  -  .
# 2         21  .  TF_binding_site   5011007   5011021 -19.820695  +  .
# 3         21  .  TF_binding_site   5011007   5011021 -19.820695  +  .
# 4         21  .  TF_binding_site   5011007   5011021 -19.820695  +  .
# ...       .. ..              ...       ...       ...        ... .. ..
# 13673861  21  .  TF_binding_site  46699954  46699968   1.717126  -  .
# 13673862  21  .  TF_binding_site  46699954  46699968   1.717126  -  .
# 13673863  21  .  TF_binding_site  46699954  46699968   1.717126  -  .
# 13673864  21  .  TF_binding_site  46699954  46699968   1.717126  -  .
# 13673865  21  .  TF_binding_site  46699954  46699968   1.717126  -  .
#
#          binding_matrix_stable_id        stable_id         sequence  \
# ...

# %%
df = f[f['epigenomes_with_experimental_evidence'].isnull()==False]

# %%
df
# Out:
#            1  2                3         4         5         6  7  8  \
# 12587138  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587139  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587140  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587141  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587142  21  .  TF_binding_site   5012708   5012735  0.884752  -  .
# ...       .. ..              ...       ...       ...       ... .. ..
# 13673861  21  .  TF_binding_site  46699954  46699968  1.717126  -  .
# 13673862  21  .  TF_binding_site  46699954  46699968  1.717126  -  .
# 13673863  21  .  TF_binding_site  46699954  46699968  1.717126  -  .
# 13673864  21  .  TF_binding_site  46699954  46699968  1.717126  -  .
# 13673865  21  .  TF_binding_site  46699954  46699968  1.717126  -  .
#
#          binding_matrix_stable_id        stable_id  \
# 12587138               ENSPFM0120  ENSM00526051567
# ...

# %%
f22 = pd.read_csv("22_result.txt", delimiter = '\t')
# Out:
# C:\Users\Curigin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
f22
# Out:
#            1  2                3         4         5          6  7  8  \
# 0         22  .  TF_binding_site  10573002  10573010   5.392489  -  .
# 1         22  .  TF_binding_site  10573002  10573014   9.964178  -  .
# 2         22  .  TF_binding_site  10573002  10573014   9.964178  -  .
# 3         22  .  TF_binding_site  10573002  10573014   9.964178  -  .
# 4         22  .  TF_binding_site  10573003  10573021   8.880961  -  .
# ...       .. ..              ...       ...       ...        ... .. ..
# 18453273  22  .  TF_binding_site  50808389  50808402 -12.780876  +  .
# 18453274  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453275  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453276  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453277  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
#
#          binding_matrix_stable_id        stable_id             sequence  \
# ...

# %%
df2 = f22[f22['epigenomes_with_experimental_evidence'].isnull()==False]

# %%
df2
# Out:
#            1  2                3         4         5          6  7  8  \
# 16899021  22  .  TF_binding_site  10526203  10526214   5.096745  +  .
# 16899022  22  .  TF_binding_site  10526203  10526214   5.096745  +  .
# 16899023  22  .  TF_binding_site  10526207  10526221   6.811407  -  .
# 16899024  22  .  TF_binding_site  10526207  10526221   6.811407  -  .
# 16899025  22  .  TF_binding_site  10526207  10526221   6.811407  -  .
# ...       .. ..              ...       ...       ...        ... .. ..
# 18453273  22  .  TF_binding_site  50808389  50808402 -12.780876  +  .
# 18453274  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453275  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453276  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453277  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
#
#          binding_matrix_stable_id        stable_id           sequence  \
# ...

# %%
result = pd.concat([df, df2])
result
# Out:
#            1  2                3         4         5          6  7  8  \
# 12587138  21  .  TF_binding_site   5012620   5012634  -3.190052  +  .
# 12587139  21  .  TF_binding_site   5012620   5012634  -3.190052  +  .
# 12587140  21  .  TF_binding_site   5012620   5012634  -3.190052  +  .
# 12587141  21  .  TF_binding_site   5012620   5012634  -3.190052  +  .
# 12587142  21  .  TF_binding_site   5012708   5012735   0.884752  -  .
# ...       .. ..              ...       ...       ...        ... .. ..
# 18453273  22  .  TF_binding_site  50808389  50808402 -12.780876  +  .
# 18453274  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453275  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453276  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
# 18453277  22  .  TF_binding_site  50808390  50808406  -7.325674  -  .
#
#          binding_matrix_stable_id        stable_id  \
# 12587138               ENSPFM0120  ENSM00526051567
# ...

# %%
f3 = pd.read_csv("20_result.txt", delimiter = '\t')
# Out:
# C:\Users\Curigin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
f3
# Out:
#            1  2                3         4         5         6  7  8  \
# 0         20  .  TF_binding_site     65001     65014 -0.642017  -  .
# 1         20  .  TF_binding_site     65001     65018 -1.076520  -  .
# 2         20  .  TF_binding_site     65001     65018 -1.076520  -  .
# 3         20  .  TF_binding_site     65001     65020  0.070796  -  .
# 4         20  .  TF_binding_site     65001     65020  0.070796  -  .
# ...       .. ..              ...       ...       ...       ... .. ..
# 29062968  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062969  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062970  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062971  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062972  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
#
#          binding_matrix_stable_id        stable_id              sequence  \
# ...

# %%
df3 = f3[f3['epigenomes_with_experimental_evidence'].isnull()==False]
df3
# Out:
#            1  2                3         4         5          6  7  8  \
# 26481323  20  .  TF_binding_site     60098     60125 -13.849289  -  .
# 26481324  20  .  TF_binding_site     60098     60125 -13.849289  -  .
# 26481325  20  .  TF_binding_site     60101     60123   6.453941  +  .
# 26481326  20  .  TF_binding_site     60101     60123   6.453941  +  .
# 26481327  20  .  TF_binding_site     60104     60123   3.818729  +  .
# ...       .. ..              ...       ...       ...        ... .. ..
# 29062968  20  .  TF_binding_site  64331507  64331520   0.452973  +  .
# 29062969  20  .  TF_binding_site  64331507  64331520   0.452973  +  .
# 29062970  20  .  TF_binding_site  64331507  64331520   0.452973  +  .
# 29062971  20  .  TF_binding_site  64331507  64331520   0.452973  +  .
# 29062972  20  .  TF_binding_site  64331507  64331520   0.452973  +  .
#
#          binding_matrix_stable_id        stable_id  \
# 26481323               ENSPFM0239  ENSM00525169321
# ...

# %%
result = pd.concat([df, df2, df3])
result
# Out:
#            1  2                3         4         5         6  7  8  \
# 12587138  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587139  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587140  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587141  21  .  TF_binding_site   5012620   5012634 -3.190052  +  .
# 12587142  21  .  TF_binding_site   5012708   5012735  0.884752  -  .
# ...       .. ..              ...       ...       ...       ... .. ..
# 29062968  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062969  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062970  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062971  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
# 29062972  20  .  TF_binding_site  64331507  64331520  0.452973  +  .
#
#          binding_matrix_stable_id        stable_id  \
# 12587138               ENSPFM0120  ENSM00526051567
# ...

# %%
result.to_csv("testresult.txt", sep = '\t', index = False)
