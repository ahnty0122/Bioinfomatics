# %%
import pandas as pd

f1 = pd.read_csv('9606.protein.actions.detailed.v9.1.txt', sep = '\t')

# %%
f1
# Out:
#                    item_id_a             item_id_b        mode      action  \
# 0       9606.ENSP00000000233  9606.ENSP00000294179     binding         NaN
# 1       9606.ENSP00000000233  9606.ENSP00000282606     binding         NaN
# 2       9606.ENSP00000000233  9606.ENSP00000234626     binding         NaN
# 3       9606.ENSP00000000233  9606.ENSP00000229319     binding         NaN
# 4       9606.ENSP00000000233  9606.ENSP00000223369     binding         NaN
# ...                      ...                   ...         ...         ...
# 926125  9606.ENSP00000420825  9606.ENSP00000296871  expression  inhibition
# 926126  9606.ENSP00000420825  9606.ENSP00000304283  expression         NaN
# 926127  9606.ENSP00000420828  9606.ENSP00000312435     binding         NaN
# 926128  9606.ENSP00000420828  9606.ENSP00000318520     binding         NaN
# 926129  9606.ENSP00000420828  9606.ENSP00000415481     binding         NaN
#
#         a_is_acting  score sources transferred_sources
# ...

# %%
lists = f1['action']

# %%
temp = pd.Series(lists)
print(temp.value_counts())
# Out:
# activation    25042
# inhibition    14060
# Name: action, dtype: int64

# %%
f2 = pd.read_csv('9606.protein.links.detailed.v9.1.txt', sep = ' ')

# %%
f2
# Out:
#                      protein1              protein2  neighborhood  fusion  \
# 0        9606.ENSP00000000233  9606.ENSP00000020673             0       0
# 1        9606.ENSP00000000233  9606.ENSP00000054666             0       0
# 2        9606.ENSP00000000233  9606.ENSP00000158762             0       0
# 3        9606.ENSP00000000233  9606.ENSP00000203407             0       0
# 4        9606.ENSP00000000233  9606.ENSP00000203630             0       0
# ...                       ...                   ...           ...     ...
# 4850623  9606.ENSP00000420828  9606.ENSP00000376623             0       0
# 4850624  9606.ENSP00000420828  9606.ENSP00000377944             0       0
# 4850625  9606.ENSP00000420828  9606.ENSP00000381436             0       0
# 4850626  9606.ENSP00000420828  9606.ENSP00000415481             0       0
# 4850627  9606.ENSP00000420828  9606.ENSP00000419266             0       0
#
#          cooccurence  coexpression  experimental  database  textmining  \
# ...
