# %%
import psycopg2
import pandas as pd

# %%
conn_string = "host = 'localhost' dbname = 'string' user = 'postgres' password = '9860'"
conn = psycopg2.connect(conn_string)
cur = conn.cursor()

# %%
#################################################### schema: evidence

# %%
# collections
cur.execute("SELECT collection_id, pubmed_id, comment FROM evidence.collections limit 10;")
result = cur.fetchall()

# %%
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    collection_id pubmed_id                                            comment
# 0       biocarta            Pathways from BioCarta, as of September 2018. ...
# 1         biocyc  29447345  BioCyc/EcoCyc Pathways as of September 2018. P...
# 2         brenda            Brenda Enzyme database, indirectly accessed vi...
# 3  cell_ontology            Cell ontology annotations, indirectly accessed...
# 4            dip  14681454  DIP interaction database, dated September 2018...
# 5            efo                                 Experimental Factor Ontology
# 6           emdb            Electron Microscopy Databank, indirectly acces...
# 7    flannotator  19126575  Flannotator database, indirectly accessed via ...
# 8  gene_ontology  27899567  Protein complexes annotated by the Gene Ontolo...
# 9           grid  30476227  BioGRID interaction database, imported October...

# %%
# sets
cur.execute("SELECT set_id, collection_id, title, comment, url FROM evidence.sets limit 10;")
result = cur.fetchall()
result
# Out:
# [('aac00010',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Glycolysis / Gluconeogenesis',
#   'http://www.kegg.jp/kegg-bin/show_pathway?aac00010'),
#  ('aac00020',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Citrate cycle (TCA cycle)',
#   'http://www.kegg.jp/kegg-bin/show_pathway?aac00020'),
#  ('aac00030',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Pentose phosphate pathway',
#   'http://www.kegg.jp/kegg-bin/show_pathway?aac00030'),
#  ('aac00040',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Pentose and glucuronate interconversions',
#   'http://www.kegg.jp/kegg-bin/show_pathway?aac00040'),
#  ('aac00051',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Fructose and mannose metabolism',
#   'http://www.kegg.jp/kegg-bin/show_pathway?aac00051'),
#  ('aac00052',
#   'kegg_pathways',
#   'annotated pathway (KEGG)',
#   'Name: Galactose metabolism',
# ...

# %%
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#      set_id  collection_id                     title  \
# 0  aac00010  kegg_pathways  annotated pathway (KEGG)
# 1  aac00020  kegg_pathways  annotated pathway (KEGG)
# 2  aac00030  kegg_pathways  annotated pathway (KEGG)
# 3  aac00040  kegg_pathways  annotated pathway (KEGG)
# 4  aac00051  kegg_pathways  annotated pathway (KEGG)
# 5  aac00052  kegg_pathways  annotated pathway (KEGG)
# 6  aac00053  kegg_pathways  annotated pathway (KEGG)
# 7  aac00061  kegg_pathways  annotated pathway (KEGG)
# 8  aac00071  kegg_pathways  annotated pathway (KEGG)
# 9  aac00072  kegg_pathways  annotated pathway (KEGG)
#
#                                             comment  \
# 0                Name: Glycolysis / Gluconeogenesis
# 1                   Name: Citrate cycle (TCA cycle)
# 2                   Name: Pentose phosphate pathway
# 3    Name: Pentose and glucuronate interconversions
# 4             Name: Fructose and mannose metabolism
# 5                        Name: Galactose metabolism
# ...

# %%
# sets_items
cur.execute("SELECT set_id, item_id, species_id, preferred_name, set_type FROM evidence.sets_items limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#      set_id  item_id  species_id preferred_name set_type
# 0  BCRT1000  4432734        9606           CPB2        d
# 1  BCRT1000  4438421        9606             F2        d
# 2  BCRT1000  4439430        9606            F2R        d
# 3  BCRT1001  4433442        9606        ARHGDIB        d
# 4  BCRT1001  4438651        9606          CASP3        d
# 5  BCRT1002  4433405        9606          KITLG        d
# 6  BCRT1002  4436763        9606            KIT        d
# 7  BCRT1002  4448459        9606           HRAS        d
# 8  BCRT1003  4438648        9606          MAPK7        d
# 9  BCRT1003  4449746        9606        RPS6KA1        d

# %%
# sets_pubmedrefs
cur.execute("SELECT set_id, pubmed_id FROM evidence.sets_pubmedrefs limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#         set_id pubmed_id
# 0  DIP-100000E  19402753
# 1  DIP-100001E  19402753
# 2  DIP-100002E  19402753
# 3  DIP-100003E  19402753
# 4  DIP-100004E  19402753
# 5  DIP-100005E  19402753
# 6  DIP-100006E  19402753
# 7  DIP-100007E  19402753
# 8  DIP-100008E  19402753
# 9  DIP-100009E  19402753

# %%
# actions_sets
cur.execute("SELECT item_id_a, item_id_b, mode, sources FROM evidence.actions_sets limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    item_id_a  item_id_b        mode        sources
# 0       6404       6436  expression  PMID021488981
# 1       6404       8012  activation  PMID028497290
# 2       6404      10035  expression  PMID028553272
# 3       6404      11197  expression  PMID021488981
# 4       6407       7912     binding  PMID018977196
# 5       6407      10254     binding  PMID026497057
# 6       6411       7713     binding  PMID024145749
# 7       6411       9562     binding  PMID028510688
# 8       6411       9562       ptmod  PMID023143271
# 9       6411      10035  expression  PMID025289006

# %%
# fusion_evidence
cur.execute("SELECT target_protein_id_a, target_protein_id_b, source_protein, source_species, transfer_score_c1, transfer_score_c2, fusion_score FROM evidence.fusion_evidence limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    target_protein_id_a  target_protein_id_b  source_protein  source_species  \
# 0                 6398                10214        23693456         1183438
# 1                 6398                 8740        23435508         1170562
# 2                 6398                11997        11612985          251221
# 3                 6398                10209        22661311         1128427
# 4                 6398                12036        11613505          251221
# 5                 6398                 6941         9747109          118173
# 6                 6398                 9604        23693473         1183438
# 7                 6398                11997        11093227          221288
# 8                 6398                10214        23693473         1183438
# 9                 6398                 8852         9747109          118173
#
#    transfer_score_c1  transfer_score_c2  fusion_score
# 0                230                 29             6
# ...

# %%
# items_publications
cur.execute("SELECT item_id, publication_id, name_shown, paragraph_number, sentence_number_in_paragraph, start_position, end_position, go_id FROM evidence.items_publications limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    item_id publication_id             name_shown  paragraph_number  \
# 0     6397   PMID:8820243  putative DNA helicase                 2
# 1     6397   PMID:8820243  putative DNA helicase                 1
# 2     6398  PMID:23516524                   nasS                65
# 3     6398  PMID:24005668                   NasS                24
# 4     6398  PMID:24005668                   NasS                25
# 5     6398  PMID:24005668                   NasS                25
# 6     6398  PMID:24005668                   NasS                 2
# 7     6398  PMID:24005668                   NasS                 2
# 8     6398  PMID:24005668                   NasS                27
# 9     6398  PMID:24005668                   NasS                 2
#
#    sentence_number_in_paragraph  start_position  end_position  go_id
# 0                             1             309           329      0
# 1                             1              92           112      0
# ...

# %%
# publications
cur.execute("SELECT publication_id, publication_date, publication_source, linkout_url, authors, title, abstract FROM evidence.publications limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#   publication_id  publication_date publication_source  \
# 0    OMIM:100070                 0               OMIM
# 1    OMIM:100300                 0               OMIM
# 2    OMIM:100600                 0               OMIM
# 3    OMIM:100640                 0               OMIM
# 4    OMIM:100650                 0               OMIM
# 5    OMIM:100660                 0               OMIM
# 6    OMIM:100670                 0               OMIM
# 7    OMIM:100678                 0               OMIM
# 8    OMIM:100690                 0               OMIM
# 9    OMIM:100710                 0               OMIM
#
#                     linkout_url authors  \
# 0  http://omim.org/entry/100070
# 1  http://omim.org/entry/100300
# 2  http://omim.org/entry/100600
# 3  http://omim.org/entry/100640
# 4  http://omim.org/entry/100650
# 5  http://omim.org/entry/100660
# 6  http://omim.org/entry/100670
# 7  http://omim.org/entry/100678
# 8  http://omim.org/entry/100690
# ...

# %%
#################################################### schema: network

# %%
# actions
cur.execute("SELECT item_id_a, item_id_b, mode, action, is_directional, a_is_acting, score FROM network.actions limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    item_id_a  item_id_b       mode action  is_directional  a_is_acting  score
# 0       6397       8169    binding                  False        False    152
# 1       6397       8264    binding                  False        False    457
# 2       6397       8264  catalysis                   True        False    457
# 3       6397       8264  catalysis                   True         True    457
# 4       6397       8264   reaction                  False        False    457
# 5       6397       8264   reaction                   True        False    457
# 6       6397       8264   reaction                   True         True    457
# 7       6397       8440    binding                  False        False    479
# 8       6397       8440  catalysis                   True        False    457
# 9       6397       8440  catalysis                   True         True    457

# %%
# node_node_links
cur.execute("SELECT node_id_a, node_type_b, node_id_b, combined_score, evidence_scores FROM network.node_node_links limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    node_id_a  node_type_b  node_id_b  combined_score  \
# 0       6396          287      11849             547
# 1       6396          287      11851             547
# 2       6396          287      11848             547
# 3       6396          287      11850             547
# 4       6397          287      12012             254
# 5       6397          287       8417             253
# 6       6397          287       6543             228
# 7       6397          287       6710             524
# 8       6397          287       8415             352
# 9       6397          287      12110             209
#
#                            evidence_scores
# 0                               [[1, 547]]
# 1                               [[1, 547]]
# 2                               [[1, 547]]
# 3                               [[1, 547]]
# 4                      [[2, 68], [6, 233]]
# 5                      [[2, 63], [6, 236]]
# 6  [[2, 66], [7, 112], [9, 102], [13, 86]]
# ...

# %%
#################################################### schema: items

# %%
# runs
cur.execute("SELECT * FROM items.runs limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    run_id  species_id     contig_id
# 0       1      272951  AABW01000001
# 1       2      272951  AABW01000001
# 2       3      272951  AABW01000001
# 3       4      272951  AABW01000001
# 4       5      272951  AABW01000001
# 5       6      272951  AABW01000001
# 6       7      272951  AABW01000001
# 7       8      272951  AABW01000001
# 8       9      272951  AABW01000001
# 9      10      272951  AABW01000001

# %%
# runs_genes_proteins
cur.execute("SELECT * FROM items.runs_genes_proteins limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    run_id   gene_id  protein_id  start_position_on_contig  \
# 0       1  11085287    11964767                         4
# 1       2  11085288    11964768                      1222
# 2       2  11085289    11964769                      2593
# 3       2  11085290    11964770                      3202
# 4       2  11085291    11964771                      3682
# 5       2  11085292    11964772                      3842
# 6       2  11085293    11964773                      4016
# 7       2  11085294    11964774                      4680
# 8       2  11085295    11964775                      4990
# 9       2  11085296    11964776                      6073
#
#    end_position_on_contig preferred_name  \
# 0                     176     rsib_orf01
# 1                     154           prfA
# 2                    1354     rsib_orf03
# 3                    2728           infC
# 4                    3352     rsib_orf05
# 5                    3668     rsib_orf06
# ...

# %%
# proteins_linkouts
cur.execute("SELECT protein_id, linkout_type, is_primary_linkout, linkout_url FROM items.proteins_linkouts limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    protein_id linkout_type  is_primary_linkout  \
# 0        6396       RefSeq                True
# 1        6397         KEGG               False
# 2        6397       RefSeq                True
# 3        6397      UniProt               False
# 4        6398         KEGG               False
# 5        6398       RefSeq                True
# 6        6398      UniProt               False
# 7        6399         KEGG               False
# 8        6399       RefSeq                True
# 9        6399      UniProt               False
#
#                                          linkout_url
# 0      https://www.ncbi.nlm.nih.gov/protein/KFL14205
# 1  https://www.genome.jp/dbget-bin/www_bget?paeb:...
# 2      https://www.ncbi.nlm.nih.gov/protein/KFL12502
# 3   https://www.uniprot.org/uniprot/A0A0A8RLT5_PSEAI
# 4  https://www.genome.jp/dbget-bin/www_bget?paeb:...
# 5      https://www.ncbi.nlm.nih.gov/protein/KFL13127
# 6   https://www.uniprot.org/uniprot/A0A0A8RPW1_PSEAI
# ...

# %%
# proteins_names (species_id = 9606 사람)
cur.execute("SELECT protein_name, protein_id, species_id, source, is_preferred_name FROM items.proteins_names WHERE species_id = '9606' limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#     protein_name  protein_id  species_id                      source  \
# 0  0610037N12Rik     4438044        9606  Ensembl_EntrezGene_synonym
# 1  0610037N12Rik     4438044        9606     BLAST_KEGG_NAME_SYNONYM
# 2  0710008D09Rik     4450843        9606     BLAST_KEGG_NAME_SYNONYM
# 3  0710008D09Rik     4450843        9606  Ensembl_EntrezGene_synonym
# 4              1     4444301        9606  Ensembl_EntrezGene_synonym
# 5              1     4439729        9606  Ensembl_EntrezGene_synonym
# 6              1     4436430        9606  Ensembl_EntrezGene_synonym
# 7        1.-.-.-     4446982        9606               BLAST_KEGG_EC
# 8        1.-.-.-     4445083        9606               BLAST_KEGG_EC
# 9        1.-.-.-     4437438        9606               BLAST_KEGG_EC
#
#    is_preferred_name
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# 5              False
# 6              False
# 7              False
# ...

# %%
# proteins (spiecies_id = 9609 사람)
cur.execute("SELECT protein_id, protein_external_id, species_id, protein_checksum, protein_size, annotation, preferred_name, annotation_word_vectors FROM items.proteins WHERE species_id = '9606' limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    protein_id   protein_external_id  species_id  protein_checksum  \
# 0     4432544  9606.ENSP00000000233        9606  25EF3D4895408147
# 1     4432545  9606.ENSP00000000412        9606  1093FE25DEB6C8E8
# 2     4432546  9606.ENSP00000001008        9606  6A498105418D9435
# 3     4432547  9606.ENSP00000001146        9606  A06D1D9944E6726F
# 4     4432548  9606.ENSP00000002125        9606  9F3D667CCE470623
# 5     4432549  9606.ENSP00000002165        9606  A42AA6B369A3AC39
# 6     4432550  9606.ENSP00000002596        9606  AA1052260633EA1C
# 7     4432551  9606.ENSP00000002829        9606  FE3FC796EEC1608E
# 8     4432552  9606.ENSP00000003084        9606  8D082AA2E768C065
# 9     4432553  9606.ENSP00000003100        9606  F9145DDB65F94091
#
#    protein_size                                         annotation  \
# 0           180  ADP-ribosylation factor 5; GTP-binding protein...
# 1           277  Cation-dependent mannose-6-phosphate receptor;...
# ...

# %%
# genes
cur.execute("SELECT gene_id, gene_external_id, start_position_on_contig, end_position_on_contig, protein_size FROM items.genes limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    gene_id                         gene_external_id  start_position_on_contig  \
# 0        1   1000565.METUNv1_00006.AFHG01000010.118                       118
# 1        2   1000565.METUNv1_00011.AFHG01000014.104                       104
# 2        3    1000565.METUNv1_00018.AFHG01000020.56                        56
# 3        4   1000565.METUNv1_00019.AFHG01000020.572                       572
# 4        5   1000565.METUNv1_00035.AFHG01000028.487                       487
# 5        6  1000565.METUNv1_00036.AFHG01000028.1886                      1886
# 6        7  1000565.METUNv1_00037.AFHG01000028.2560                      2560
# 7        8  1000565.METUNv1_00038.AFHG01000028.3991                      3991
# 8        9  1000565.METUNv1_00041.AFHG01000028.6682                      6682
# 9       10  1000565.METUNv1_00042.AFHG01000028.8667                      8667
#
#    end_position_on_contig  protein_size
# 0                    1166           349
# ...

# %%
# genes_proteins
cur.execute("SELECT protein_id, gene_id FROM items.genes_proteins limit 10;")
result = cur.fetchall()
my_df = pd.DataFrame(result)
my_df.columns = [desc[0] for desc in cur.description]
my_df
# Out:
#    protein_id   gene_id
# 0        6396  11389400
# 1        6397  11389401
# 2        6398  11389402
# 3        6399  11389403
# 4        6400  11389404
# 5        6401  11389405
# 6        6402  11389406
# 7        6403  11389407
# 8        6404  11389408
# 9        6405  11389409

# %%
####################################################

# %%
#################################################### practice

# %%
# action 있는 것만 가져오기

cur.execute("SELECT item_id_a, item_id_b, mode, action, is_directional, a_is_acting, score FROM network.actions WHERE action != '';")
result = cur.fetchall()
action = pd.DataFrame(result)
action.columns = [desc[0] for desc in cur.description]
action
# Out:
#            item_id_a  item_id_b        mode      action  is_directional  \
# 0               6397       7812  activation  activation           False
# 1               6404       8012  activation  activation            True
# 2               6404       6436  expression  inhibition            True
# 3               6404       6436  activation  activation            True
# 4               6404      11197  expression  inhibition            True
# ...              ...        ...         ...         ...             ...
# 168324681   29519129   29517941  activation  activation           False
# 168324682   29519134   29518776  activation  activation           False
# 168324683   29519137   29516714  activation  activation           False
# 168324684   29519137   29516988  activation  activation           False
# 168324685   29519137   29517941  activation  activation           False
#
#            a_is_acting  score
# 0                False    167
# 1                False    429
# ...
